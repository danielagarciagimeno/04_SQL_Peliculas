# %% [markdown]
# TITLE

# %%
import pandas as pd

# 1. Cargar el archivo CSV en un DataFrame
df = pd.read_csv('./titles_combinado.csv')

# %%
df = df.drop(columns=['genre_title', 'country_title', 'platform_title'])

# %%
df.head()
# Out:
#    id_titles                        title   type  \
# 0        tm1                    Star Wars  MOVIE
# 1       tm10                   The Matrix  MOVIE
# 2    tm10000                    Jury Duty  MOVIE
# 3   tm100001              The Lucky Texan  MOVIE
# 4  tm1000022  Boonie Bears: The Wild Life  MOVIE
#
#                                          description  release_year  \
# 0  Princess Leia is captured and held hostage by ...          1977
# 1  Set in the 22nd century, The Matrix tells the ...          1999
# 2  When jobless Tommy Collins discovers that sequ...          1995
# 3  Jerry Mason, a young Texan, and Jake Benson, a...          1934
# 4  Bear brothers Briar and Bramble set off on an ...          2021
#
#   age_certification  runtime  seasons     imdb_id  imdb_score  imdb_votes  \
# 0                PG      121      0.0   tt0076759         8.6   1378285.0
# 1                 R      136      0.0   tt0133093         8.7   1934137.0
# ...

# %%
df.to_csv('./titles.csv')
